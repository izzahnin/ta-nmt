# %%
import json
import subprocess
import time
from pathlib import Path

class OllamaBatchTranslator:
    def __init__(self, source_file: str, output_file: str, batch_size=10, model="lauchacarro/qwen2.5-translator"):
        self.source_file = Path(source_file)
        self.output_file = Path(output_file)
        self.batch_size = batch_size
        self.model = model
        self.checkpoint_file = self.output_file.parent / "checkpoint.json"

        self.stats = self._load_checkpoint() or {
            'processed_index': 0,
            'start_time': time.time()
        }

        self._load_source()

    def _load_checkpoint(self):
        if self.checkpoint_file.exists():
            with open(self.checkpoint_file, 'r', encoding='utf-8') as f:
                return json.load(f)
        return None

    def _save_checkpoint(self):
        with open(self.checkpoint_file, 'w', encoding='utf-8') as f:
            json.dump(self.stats, f, indent=2, ensure_ascii=False)

    def _load_source(self):
        with open(self.source_file, 'r', encoding='utf-8') as f:
            self.source_data = json.load(f)

    def _translate_batch(self, batch):
        prompt_lines = "\n".join([f"{i+1}. {text}" for i, text in enumerate(batch)])
        prompt = (
            "Terjemahkan semua kalimat ini ke dalam Bahasa Indonesia secara kontekstual dan ilmiah sesuai bidang ornitologi:\n\n"
            f"{prompt_lines}\n\nJawaban:"
        )

        result = subprocess.run(
            ["ollama", "run", self.model],
            input=prompt.encode(),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE
        )
        output = result.stdout.decode("utf-8").strip()

        lines = output.split("\n")
        translations = []
        for line in lines:
            if "." in line:
                text = line.split(".", 1)[1].strip()
                if text:
                    translations.append(text)
        return translations

    def run(self):
        print("\n=== Starting Translation with Checkpoint Support ===")
        index = self.stats['processed_index']

        all_entries = []
        for entry_idx, entry in enumerate(self.source_data["dataset"]):
            for cap_idx, cap in enumerate(entry["captions"]):
                all_entries.append((entry_idx, cap_idx, cap["english"]))

        while index < len(all_entries):
            batch_entries = all_entries[index:index + self.batch_size]
            batch_texts = [item[2] for item in batch_entries]

            print(f"\n🔁 Translating batch {index} to {index + len(batch_entries) - 1}...")
            translations = self._translate_batch(batch_texts)

            for i, (entry_idx, cap_idx, _) in enumerate(batch_entries):
                self.source_data["dataset"][entry_idx]["captions"][cap_idx]["indo"] = (
                    translations[i] if i < len(translations) else "[MISSING TRANSLATION]"
                )

            index += self.batch_size
            self.stats['processed_index'] = index
            self._save_checkpoint()
            print(f"✅ Saved checkpoint at index {index}")
            time.sleep(1)

        print("\n🎉 Translation complete!")
        with open(self.output_file, 'w', encoding='utf-8') as f:
            json.dump(self.source_data, f, indent=2, ensure_ascii=False)
        print(f"📝 Results saved to: {self.output_file}")

# %%
processor = OllamaBatchTranslator(
    source_file="paralel_cub_200_2011_captions.json",
    output_file="ollama_translated.json",
    batch_size=10
)
processor.run()
# Out:
# === Starting Translation with Checkpoint Support ===
#
# 🔁 Translating batch 0 to 9...
# ✅ Saved checkpoint at index 10
#
# 🔁 Translating batch 10 to 19...
# ✅ Saved checkpoint at index 20
#
# 🔁 Translating batch 20 to 29...
# ✅ Saved checkpoint at index 30
#
# 🔁 Translating batch 30 to 39...
# ✅ Saved checkpoint at index 40
#
# 🔁 Translating batch 40 to 49...
# ✅ Saved checkpoint at index 50
#
# 🔁 Translating batch 50 to 59...
# ✅ Saved checkpoint at index 60
#
# 🔁 Translating batch 60 to 69...
# ✅ Saved checkpoint at index 70
#
# 🔁 Translating batch 70 to 79...
# ✅ Saved checkpoint at index 80
#
# 🔁 Translating batch 80 to 89...
# ✅ Saved checkpoint at index 90
#
# 🔁 Translating batch 90 to 99...
# ✅ Saved checkpoint at index 100
#
# 🔁 Translating batch 100 to 109...
# ✅ Saved checkpoint at index 110
#
# 🔁 Translating batch 110 to 119...
# ✅ Saved checkpoint at index 120
#
# 🔁 Translating batch 120 to 129...
# ✅ Saved checkpoint at index 130
#
# 🔁 Translating batch 130 to 139...
# ✅ Saved checkpoint at index 140
#
# 🔁 Translating batch 140 to 149...
# ✅ Saved checkpoint at index 150
#
# 🔁 Translating batch 150 to 159...
# ✅ Saved checkpoint at index 160
#
# 🔁 Translating batch 160 to 169...
# ✅ Saved checkpoint at index 170
#
# 🔁 Translating batch 170 to 179...
# ✅ Saved checkpoint at index 180
#
# 🔁 Translating batch 180 to 189...
# ✅ Saved checkpoint at index 190
#
# 🔁 Translating batch 190 to 199...
# ✅ Saved checkpoint at index 200
#
# 🔁 Translating batch 200 to 209...
# ✅ Saved checkpoint at index 210
#
# 🔁 Translating batch 210 to 219...
# ✅ Saved checkpoint at index 220
#
# 🔁 Translating batch 220 to 229...
# ✅ Saved checkpoint at index 230
#
# 🔁 Translating batch 230 to 239...
# ✅ Saved checkpoint at index 240
#
# 🔁 Translating batch 240 to 249...
# ✅ Saved checkpoint at index 250
#
# 🔁 Translating batch 250 to 259...
# ✅ Saved checkpoint at index 260
#
# 🔁 Translating batch 260 to 269...
# ✅ Saved checkpoint at index 270
#
# 🔁 Translating batch 270 to 279...
# ✅ Saved checkpoint at index 280
#
# 🔁 Translating batch 280 to 289...
# ✅ Saved checkpoint at index 290
#
# 🔁 Translating batch 290 to 299...
# ✅ Saved checkpoint at index 300
#
# 🔁 Translating batch 300 to 309...
# ✅ Saved checkpoint at index 310
#
# 🔁 Translating batch 310 to 319...
# ✅ Saved checkpoint at index 320
#
# 🔁 Translating batch 320 to 329...
# ✅ Saved checkpoint at index 330
#
# 🔁 Translating batch 330 to 339...
# ✅ Saved checkpoint at index 340
#
# 🔁 Translating batch 340 to 349...
# ✅ Saved checkpoint at index 350
#
# 🔁 Translating batch 350 to 359...
# ✅ Saved checkpoint at index 360
#
# 🔁 Translating batch 360 to 369...
# ✅ Saved checkpoint at index 370
#
# 🔁 Translating batch 370 to 379...
# ✅ Saved checkpoint at index 380
#
# 🔁 Translating batch 380 to 389...
# ✅ Saved checkpoint at index 390
#
# 🔁 Translating batch 390 to 399...
# ✅ Saved checkpoint at index 400
#
# 🔁 Translating batch 400 to 409...
# ✅ Saved checkpoint at index 410
#
# 🔁 Translating batch 410 to 419...
# ✅ Saved checkpoint at index 420
#
# 🔁 Translating batch 420 to 429...
# ✅ Saved checkpoint at index 430
#
# 🔁 Translating batch 430 to 439...
# ✅ Saved checkpoint at index 440
#
# 🔁 Translating batch 440 to 449...
# ✅ Saved checkpoint at index 450
#
# 🔁 Translating batch 450 to 459...
# ✅ Saved checkpoint at index 460
#
# 🔁 Translating batch 460 to 469...
# ✅ Saved checkpoint at index 470
#
# 🔁 Translating batch 470 to 479...
# ✅ Saved checkpoint at index 480
#
# 🔁 Translating batch 480 to 489...
# ✅ Saved checkpoint at index 490
#
# 🔁 Translating batch 490 to 499...
# ✅ Saved checkpoint at index 500
#
# 🔁 Translating batch 500 to 509...
# ✅ Saved checkpoint at index 510
#
# 🔁 Translating batch 510 to 519...
# ✅ Saved checkpoint at index 520
#
# 🔁 Translating batch 520 to 529...
# ✅ Saved checkpoint at index 530
#
# 🔁 Translating batch 530 to 539...
# ✅ Saved checkpoint at index 540
#
# 🔁 Translating batch 540 to 549...
# ✅ Saved checkpoint at index 550
#
# 🔁 Translating batch 550 to 559...
# ✅ Saved checkpoint at index 560
#
# 🔁 Translating batch 560 to 569...
# ✅ Saved checkpoint at index 570
#
# 🔁 Translating batch 570 to 579...
# ✅ Saved checkpoint at index 580
#
# 🔁 Translating batch 580 to 589...
# ✅ Saved checkpoint at index 590
#
# 🔁 Translating batch 590 to 599...
# ✅ Saved checkpoint at index 600
#
# 🔁 Translating batch 600 to 609...
# ✅ Saved checkpoint at index 610
#
# 🔁 Translating batch 610 to 619...
# ✅ Saved checkpoint at index 620
#
# 🔁 Translating batch 620 to 629...
# ✅ Saved checkpoint at index 630
#
# 🔁 Translating batch 630 to 639...
# ✅ Saved checkpoint at index 640
#
# 🔁 Translating batch 640 to 649...
# ✅ Saved checkpoint at index 650
#
# 🔁 Translating batch 650 to 659...
# ✅ Saved checkpoint at index 660
#
# 🔁 Translating batch 660 to 669...
# ✅ Saved checkpoint at index 670
#
# 🔁 Translating batch 670 to 679...
# ✅ Saved checkpoint at index 680
#
# 🔁 Translating batch 680 to 689...
# ✅ Saved checkpoint at index 690
#
# 🔁 Translating batch 690 to 699...
# ✅ Saved checkpoint at index 700
#
# 🔁 Translating batch 700 to 709...
# ✅ Saved checkpoint at index 710
#
# 🔁 Translating batch 710 to 719...
# ✅ Saved checkpoint at index 720
#
# 🔁 Translating batch 720 to 729...
# ✅ Saved checkpoint at index 730
#
# 🔁 Translating batch 730 to 739...
# ✅ Saved checkpoint at index 740
#
# 🔁 Translating batch 740 to 749...
# ✅ Saved checkpoint at index 750
#
# 🔁 Translating batch 750 to 759...
# ✅ Saved checkpoint at index 760
#
# 🔁 Translating batch 760 to 769...
# ✅ Saved checkpoint at index 770
#
# 🔁 Translating batch 770 to 779...
# ✅ Saved checkpoint at index 780
#
# 🔁 Translating batch 780 to 789...
# ✅ Saved checkpoint at index 790
#
# 🔁 Translating batch 790 to 799...
# ✅ Saved checkpoint at index 800
#
# 🔁 Translating batch 800 to 809...
# ✅ Saved checkpoint at index 810
#
# 🔁 Translating batch 810 to 819...
# ✅ Saved checkpoint at index 820
#
# 🔁 Translating batch 820 to 829...
# ✅ Saved checkpoint at index 830
#
# 🔁 Translating batch 830 to 839...
# ✅ Saved checkpoint at index 840
#
# 🔁 Translating batch 840 to 849...
# ✅ Saved checkpoint at index 850
#
# 🔁 Translating batch 850 to 859...
# ✅ Saved checkpoint at index 860
#
# 🔁 Translating batch 860 to 869...
# ✅ Saved checkpoint at index 870
#
# 🔁 Translating batch 870 to 879...
# ✅ Saved checkpoint at index 880
#
# 🔁 Translating batch 880 to 889...
# ✅ Saved checkpoint at index 890
#
# 🔁 Translating batch 890 to 899...
# ✅ Saved checkpoint at index 900
#
# 🔁 Translating batch 900 to 909...
# ✅ Saved checkpoint at index 910
#
# 🔁 Translating batch 910 to 919...
# ✅ Saved checkpoint at index 920
#
# 🔁 Translating batch 920 to 929...
# ✅ Saved checkpoint at index 930
#
# 🔁 Translating batch 930 to 939...
# ✅ Saved checkpoint at index 940
#
# 🔁 Translating batch 940 to 949...
# ✅ Saved checkpoint at index 950
#
# 🔁 Translating batch 950 to 959...
# ✅ Saved checkpoint at index 960
#
# 🔁 Translating batch 960 to 969...
# ✅ Saved checkpoint at index 970
#
# 🔁 Translating batch 970 to 979...
# ✅ Saved checkpoint at index 980
#
# 🔁 Translating batch 980 to 989...
# ✅ Saved checkpoint at index 990
#
# 🔁 Translating batch 990 to 999...
# ✅ Saved checkpoint at index 1000
#
# 🔁 Translating batch 1000 to 1009...
# ✅ Saved checkpoint at index 1010
#
# 🔁 Translating batch 1010 to 1019...
# ✅ Saved checkpoint at index 1020
#
# 🔁 Translating batch 1020 to 1029...
# ✅ Saved checkpoint at index 1030
#
# 🔁 Translating batch 1030 to 1039...
# ✅ Saved checkpoint at index 1040
#
# 🔁 Translating batch 1040 to 1049...
# ✅ Saved checkpoint at index 1050
#
# 🔁 Translating batch 1050 to 1059...
# ✅ Saved checkpoint at index 1060
#
# 🔁 Translating batch 1060 to 1069...
# ✅ Saved checkpoint at index 1070
#
# 🔁 Translating batch 1070 to 1079...
# ✅ Saved checkpoint at index 1080
#
# 🔁 Translating batch 1080 to 1089...
# ✅ Saved checkpoint at index 1090
#
# 🔁 Translating batch 1090 to 1099...
# ✅ Saved checkpoint at index 1100
#
# 🔁 Translating batch 1100 to 1109...
# ✅ Saved checkpoint at index 1110
#
# 🔁 Translating batch 1110 to 1119...
# ✅ Saved checkpoint at index 1120
#
# 🔁 Translating batch 1120 to 1129...
# ✅ Saved checkpoint at index 1130
#
# 🔁 Translating batch 1130 to 1139...
# ✅ Saved checkpoint at index 1140
#
# 🔁 Translating batch 1140 to 1149...
# ✅ Saved checkpoint at index 1150
#
# 🔁 Translating batch 1150 to 1159...
# ✅ Saved checkpoint at index 1160
#
# 🔁 Translating batch 1160 to 1169...
# ✅ Saved checkpoint at index 1170
#
# 🔁 Translating batch 1170 to 1179...
# ✅ Saved checkpoint at index 1180
#
# 🔁 Translating batch 1180 to 1189...
# ✅ Saved checkpoint at index 1190
#
# 🔁 Translating batch 1190 to 1199...
# ✅ Saved checkpoint at index 1200
#
# 🔁 Translating batch 1200 to 1209...
# ✅ Saved checkpoint at index 1210
#
# 🔁 Translating batch 1210 to 1219...
# ✅ Saved checkpoint at index 1220
#
# 🔁 Translating batch 1220 to 1229...
# ✅ Saved checkpoint at index 1230
#
# 🔁 Translating batch 1230 to 1239...
# ✅ Saved checkpoint at index 1240
#
# 🔁 Translating batch 1240 to 1249...
# ✅ Saved checkpoint at index 1250
#
# 🔁 Translating batch 1250 to 1259...
# ✅ Saved checkpoint at index 1260
#
# 🔁 Translating batch 1260 to 1269...
# ✅ Saved checkpoint at index 1270
#
# 🔁 Translating batch 1270 to 1279...
# ✅ Saved checkpoint at index 1280
#
# 🔁 Translating batch 1280 to 1289...
# ✅ Saved checkpoint at index 1290
#
# 🔁 Translating batch 1290 to 1299...
# ✅ Saved checkpoint at index 1300
#
# 🔁 Translating batch 1300 to 1309...
# ✅ Saved checkpoint at index 1310
#
# 🔁 Translating batch 1310 to 1319...
# ✅ Saved checkpoint at index 1320
#
# 🔁 Translating batch 1320 to 1329...
# ✅ Saved checkpoint at index 1330
#
# 🔁 Translating batch 1330 to 1339...
# ✅ Saved checkpoint at index 1340
#
# 🔁 Translating batch 1340 to 1349...
# ✅ Saved checkpoint at index 1350
#
# 🔁 Translating batch 1350 to 1359...
# ✅ Saved checkpoint at index 1360
#
# 🔁 Translating batch 1360 to 1369...
# ✅ Saved checkpoint at index 1370
#
# 🔁 Translating batch 1370 to 1379...
# ✅ Saved checkpoint at index 1380
#
# 🔁 Translating batch 1380 to 1389...
# ✅ Saved checkpoint at index 1390
#
# 🔁 Translating batch 1390 to 1399...
# ✅ Saved checkpoint at index 1400
#
# 🔁 Translating batch 1400 to 1409...
# ✅ Saved checkpoint at index 1410
#
# 🔁 Translating batch 1410 to 1419...
# ✅ Saved checkpoint at index 1420
#
# 🔁 Translating batch 1420 to 1429...
# ✅ Saved checkpoint at index 1430
#
# 🔁 Translating batch 1430 to 1439...
# ✅ Saved checkpoint at index 1440
#
# 🔁 Translating batch 1440 to 1449...
# ✅ Saved checkpoint at index 1450
#
# 🔁 Translating batch 1450 to 1459...
# ✅ Saved checkpoint at index 1460
#
# 🔁 Translating batch 1460 to 1469...
# ✅ Saved checkpoint at index 1470
#
# 🔁 Translating batch 1470 to 1479...
# ✅ Saved checkpoint at index 1480
#
# 🔁 Translating batch 1480 to 1489...
# ✅ Saved checkpoint at index 1490
#
# 🔁 Translating batch 1490 to 1499...
# ✅ Saved checkpoint at index 1500
#
# 🔁 Translating batch 1500 to 1509...
# ✅ Saved checkpoint at index 1510
#
# 🔁 Translating batch 1510 to 1519...
# ✅ Saved checkpoint at index 1520
#
# 🔁 Translating batch 1520 to 1529...
# ✅ Saved checkpoint at index 1530
#
# 🔁 Translating batch 1530 to 1539...
# ✅ Saved checkpoint at index 1540
#
# 🔁 Translating batch 1540 to 1549...
# ✅ Saved checkpoint at index 1550
#
# 🔁 Translating batch 1550 to 1559...
# ✅ Saved checkpoint at index 1560
#
# 🔁 Translating batch 1560 to 1569...
# ✅ Saved checkpoint at index 1570
#
# 🔁 Translating batch 1570 to 1579...
# ✅ Saved checkpoint at index 1580
#
# 🔁 Translating batch 1580 to 1589...
# ✅ Saved checkpoint at index 1590
#
# 🔁 Translating batch 1590 to 1599...
# ✅ Saved checkpoint at index 1600
#
# 🔁 Translating batch 1600 to 1609...
# ✅ Saved checkpoint at index 1610
#
# 🔁 Translating batch 1610 to 1619...
# ✅ Saved checkpoint at index 1620
#
# 🔁 Translating batch 1620 to 1629...
# ✅ Saved checkpoint at index 1630
#
# 🔁 Translating batch 1630 to 1639...
# ✅ Saved checkpoint at index 1640
#
# 🔁 Translating batch 1640 to 1649...
# ✅ Saved checkpoint at index 1650
#
# 🔁 Translating batch 1650 to 1659...
# ✅ Saved checkpoint at index 1660
#
# 🔁 Translating batch 1660 to 1669...
# ✅ Saved checkpoint at index 1670
#
# 🔁 Translating batch 1670 to 1679...
# ✅ Saved checkpoint at index 1680
#
# 🔁 Translating batch 1680 to 1689...
# ✅ Saved checkpoint at index 1690
#
# 🔁 Translating batch 1690 to 1699...
# ✅ Saved checkpoint at index 1700
#
# 🔁 Translating batch 1700 to 1709...
# ✅ Saved checkpoint at index 1710
#
# 🔁 Translating batch 1710 to 1719...
# ✅ Saved checkpoint at index 1720
#
# 🔁 Translating batch 1720 to 1729...
# ✅ Saved checkpoint at index 1730
#
# 🔁 Translating batch 1730 to 1739...
# ✅ Saved checkpoint at index 1740
#
# 🔁 Translating batch 1740 to 1749...
# ✅ Saved checkpoint at index 1750
#
# 🔁 Translating batch 1750 to 1759...
# ✅ Saved checkpoint at index 1760
#
# 🔁 Translating batch 1760 to 1769...
# ✅ Saved checkpoint at index 1770
#
# 🔁 Translating batch 1770 to 1779...
# ✅ Saved checkpoint at index 1780
#
# 🔁 Translating batch 1780 to 1789...
# ✅ Saved checkpoint at index 1790
#
# 🔁 Translating batch 1790 to 1799...
# ✅ Saved checkpoint at index 1800
#
# 🔁 Translating batch 1800 to 1809...
# ✅ Saved checkpoint at index 1810
#
# 🔁 Translating batch 1810 to 1819...
# ✅ Saved checkpoint at index 1820
#
# 🔁 Translating batch 1820 to 1829...
# ✅ Saved checkpoint at index 1830
#
# 🔁 Translating batch 1830 to 1839...
# ✅ Saved checkpoint at index 1840
#
# 🔁 Translating batch 1840 to 1849...
# ✅ Saved checkpoint at index 1850
#
# 🔁 Translating batch 1850 to 1859...
# ✅ Saved checkpoint at index 1860
#
# 🔁 Translating batch 1860 to 1869...
# ✅ Saved checkpoint at index 1870
#
# 🔁 Translating batch 1870 to 1879...
# ✅ Saved checkpoint at index 1880
#
# 🔁 Translating batch 1880 to 1889...
# ✅ Saved checkpoint at index 1890
#
# 🔁 Translating batch 1890 to 1899...
# ✅ Saved checkpoint at index 1900
#
# 🔁 Translating batch 1900 to 1909...
# ✅ Saved checkpoint at index 1910
#
# 🔁 Translating batch 1910 to 1919...
# ✅ Saved checkpoint at index 1920
#
# 🔁 Translating batch 1920 to 1929...
# ✅ Saved checkpoint at index 1930
#
# 🔁 Translating batch 1930 to 1939...
# ✅ Saved checkpoint at index 1940
#
# 🔁 Translating batch 1940 to 1949...
# ✅ Saved checkpoint at index 1950
#
# 🔁 Translating batch 1950 to 1959...
# ✅ Saved checkpoint at index 1960
#
# 🔁 Translating batch 1960 to 1969...
# ✅ Saved checkpoint at index 1970
#
# 🔁 Translating batch 1970 to 1979...
# ✅ Saved checkpoint at index 1980
#
# 🔁 Translating batch 1980 to 1989...
# ✅ Saved checkpoint at index 1990
#
# 🔁 Translating batch 1990 to 1999...
# ✅ Saved checkpoint at index 2000
#
# 🔁 Translating batch 2000 to 2009...
# ✅ Saved checkpoint at index 2010
#
# 🔁 Translating batch 2010 to 2019...
# ✅ Saved checkpoint at index 2020
#
# 🔁 Translating batch 2020 to 2029...
# ✅ Saved checkpoint at index 2030
#
# 🔁 Translating batch 2030 to 2039...
# ✅ Saved checkpoint at index 2040
#
# 🔁 Translating batch 2040 to 2049...
# ✅ Saved checkpoint at index 2050
#
# 🔁 Translating batch 2050 to 2059...
# ✅ Saved checkpoint at index 2060
#
# 🔁 Translating batch 2060 to 2069...
# ✅ Saved checkpoint at index 2070
#
# 🔁 Translating batch 2070 to 2079...
# ✅ Saved checkpoint at index 2080
#
# 🔁 Translating batch 2080 to 2089...
# ✅ Saved checkpoint at index 2090
#
# 🔁 Translating batch 2090 to 2099...
# ✅ Saved checkpoint at index 2100
#
# 🔁 Translating batch 2100 to 2109...
# ✅ Saved checkpoint at index 2110
#
# 🔁 Translating batch 2110 to 2119...
# ✅ Saved checkpoint at index 2120
#
# 🔁 Translating batch 2120 to 2129...
# ✅ Saved checkpoint at index 2130
#
# 🔁 Translating batch 2130 to 2139...
# ✅ Saved checkpoint at index 2140
#
# 🔁 Translating batch 2140 to 2149...
# ✅ Saved checkpoint at index 2150
#
# 🔁 Translating batch 2150 to 2159...
# ✅ Saved checkpoint at index 2160
#
# 🔁 Translating batch 2160 to 2169...
# ✅ Saved checkpoint at index 2170
#
# 🔁 Translating batch 2170 to 2179...
# ✅ Saved checkpoint at index 2180
#
# 🔁 Translating batch 2180 to 2189...
# ✅ Saved checkpoint at index 2190
#
# 🔁 Translating batch 2190 to 2199...
# ✅ Saved checkpoint at index 2200
#
# 🔁 Translating batch 2200 to 2209...
# ✅ Saved checkpoint at index 2210
#
# 🔁 Translating batch 2210 to 2219...
# ✅ Saved checkpoint at index 2220
#
# 🔁 Translating batch 2220 to 2229...
# ✅ Saved checkpoint at index 2230
#
# 🔁 Translating batch 2230 to 2239...
# ✅ Saved checkpoint at index 2240
#
# 🔁 Translating batch 2240 to 2249...
# ✅ Saved checkpoint at index 2250
#
# 🔁 Translating batch 2250 to 2259...
# ✅ Saved checkpoint at index 2260
#
# 🔁 Translating batch 2260 to 2269...
# ✅ Saved checkpoint at index 2270
#
# 🔁 Translating batch 2270 to 2279...
# ✅ Saved checkpoint at index 2280
#
# 🔁 Translating batch 2280 to 2289...
# ✅ Saved checkpoint at index 2290
#
# 🔁 Translating batch 2290 to 2299...
# ✅ Saved checkpoint at index 2300
#
# 🔁 Translating batch 2300 to 2309...
# ✅ Saved checkpoint at index 2310
#
# 🔁 Translating batch 2310 to 2319...
# ✅ Saved checkpoint at index 2320
#
# 🔁 Translating batch 2320 to 2329...
# ✅ Saved checkpoint at index 2330
#
# 🔁 Translating batch 2330 to 2339...
# ✅ Saved checkpoint at index 2340
#
# 🔁 Translating batch 2340 to 2349...
# ✅ Saved checkpoint at index 2350
#
# 🔁 Translating batch 2350 to 2359...
# ✅ Saved checkpoint at index 2360
#
# 🔁 Translating batch 2360 to 2369...
# ✅ Saved checkpoint at index 2370
#
# 🔁 Translating batch 2370 to 2379...
# ✅ Saved checkpoint at index 2380
#
# 🔁 Translating batch 2380 to 2389...
# ✅ Saved checkpoint at index 2390
#
# 🔁 Translating batch 2390 to 2399...
# ✅ Saved checkpoint at index 2400
#
# 🔁 Translating batch 2400 to 2409...
# ✅ Saved checkpoint at index 2410
#
# 🔁 Translating batch 2410 to 2419...
# ✅ Saved checkpoint at index 2420
#
# 🔁 Translating batch 2420 to 2429...
# ✅ Saved checkpoint at index 2430
#
# 🔁 Translating batch 2430 to 2439...
# ✅ Saved checkpoint at index 2440
#
# 🔁 Translating batch 2440 to 2449...
# ✅ Saved checkpoint at index 2450
#
# 🔁 Translating batch 2450 to 2459...
# ✅ Saved checkpoint at index 2460
#
# 🔁 Translating batch 2460 to 2469...
# ✅ Saved checkpoint at index 2470
#
# 🔁 Translating batch 2470 to 2479...
# ✅ Saved checkpoint at index 2480
#
# 🔁 Translating batch 2480 to 2489...
# ✅ Saved checkpoint at index 2490
#
# 🔁 Translating batch 2490 to 2499...
# ✅ Saved checkpoint at index 2500
#
# 🔁 Translating batch 2500 to 2509...
# ✅ Saved checkpoint at index 2510
#
# 🔁 Translating batch 2510 to 2519...
# ✅ Saved checkpoint at index 2520
#
# 🔁 Translating batch 2520 to 2529...
# ✅ Saved checkpoint at index 2530
#
# 🔁 Translating batch 2530 to 2539...
# ✅ Saved checkpoint at index 2540
#
# 🔁 Translating batch 2540 to 2549...
# ✅ Saved checkpoint at index 2550
#
# 🔁 Translating batch 2550 to 2559...
# ✅ Saved checkpoint at index 2560
#
# 🔁 Translating batch 2560 to 2569...
# ✅ Saved checkpoint at index 2570
#
# 🔁 Translating batch 2570 to 2579...
# ✅ Saved checkpoint at index 2580
#
# 🔁 Translating batch 2580 to 2589...
# ✅ Saved checkpoint at index 2590
#
# 🔁 Translating batch 2590 to 2599...
# ✅ Saved checkpoint at index 2600
#
# 🔁 Translating batch 2600 to 2609...
# ✅ Saved checkpoint at index 2610
#
# 🔁 Translating batch 2610 to 2619...
# ✅ Saved checkpoint at index 2620
#
# 🔁 Translating batch 2620 to 2629...
# ✅ Saved checkpoint at index 2630
#
# 🔁 Translating batch 2630 to 2639...
# ✅ Saved checkpoint at index 2640
#
# 🔁 Translating batch 2640 to 2649...
# ✅ Saved checkpoint at index 2650
#
# 🔁 Translating batch 2650 to 2659...
# ✅ Saved checkpoint at index 2660
#
# 🔁 Translating batch 2660 to 2669...
# ✅ Saved checkpoint at index 2670
#
# 🔁 Translating batch 2670 to 2679...
# ✅ Saved checkpoint at index 2680
#
# 🔁 Translating batch 2680 to 2689...
# ✅ Saved checkpoint at index 2690
#
# 🔁 Translating batch 2690 to 2699...
# ✅ Saved checkpoint at index 2700
#
# 🔁 Translating batch 2700 to 2709...
# ✅ Saved checkpoint at index 2710
#
# 🔁 Translating batch 2710 to 2719...
# ✅ Saved checkpoint at index 2720
#
# 🔁 Translating batch 2720 to 2729...
# ✅ Saved checkpoint at index 2730
#
# 🔁 Translating batch 2730 to 2739...
# ✅ Saved checkpoint at index 2740
#
# 🔁 Translating batch 2740 to 2749...
# ✅ Saved checkpoint at index 2750
#
# 🔁 Translating batch 2750 to 2759...
# ✅ Saved checkpoint at index 2760
#
# 🔁 Translating batch 2760 to 2769...
# ✅ Saved checkpoint at index 2770
#
# 🔁 Translating batch 2770 to 2779...
# ✅ Saved checkpoint at index 2780
#
# 🔁 Translating batch 2780 to 2789...
# ✅ Saved checkpoint at index 2790
#
# 🔁 Translating batch 2790 to 2799...
# ✅ Saved checkpoint at index 2800
#
# 🔁 Translating batch 2800 to 2809...
# ✅ Saved checkpoint at index 2810
#
# 🔁 Translating batch 2810 to 2819...
# ✅ Saved checkpoint at index 2820
#
# 🔁 Translating batch 2820 to 2829...
# ✅ Saved checkpoint at index 2830
#
# 🔁 Translating batch 2830 to 2839...
# ✅ Saved checkpoint at index 2840
#
# 🔁 Translating batch 2840 to 2849...
# ✅ Saved checkpoint at index 2850
#
# 🔁 Translating batch 2850 to 2859...
# ✅ Saved checkpoint at index 2860
#
# 🔁 Translating batch 2860 to 2869...
# ✅ Saved checkpoint at index 2870
#
# 🔁 Translating batch 2870 to 2879...
# ✅ Saved checkpoint at index 2880
#
# 🔁 Translating batch 2880 to 2889...
# ✅ Saved checkpoint at index 2890
#
# 🔁 Translating batch 2890 to 2899...
# ✅ Saved checkpoint at index 2900
#
# 🔁 Translating batch 2900 to 2909...
# ✅ Saved checkpoint at index 2910
#
# 🔁 Translating batch 2910 to 2919...
# ✅ Saved checkpoint at index 2920
#
# 🔁 Translating batch 2920 to 2929...
# ✅ Saved checkpoint at index 2930
#
# 🔁 Translating batch 2930 to 2939...
# ✅ Saved checkpoint at index 2940
#
# 🔁 Translating batch 2940 to 2949...
# ✅ Saved checkpoint at index 2950
#
# 🔁 Translating batch 2950 to 2959...
# ✅ Saved checkpoint at index 2960
#
# 🔁 Translating batch 2960 to 2969...
# ✅ Saved checkpoint at index 2970
#
# 🔁 Translating batch 2970 to 2979...
# ✅ Saved checkpoint at index 2980
#
# 🔁 Translating batch 2980 to 2989...
# ✅ Saved checkpoint at index 2990
#
# 🔁 Translating batch 2990 to 2999...
# ✅ Saved checkpoint at index 3000
#
# 🔁 Translating batch 3000 to 3009...
# ✅ Saved checkpoint at index 3010
#
# 🔁 Translating batch 3010 to 3019...
# ✅ Saved checkpoint at index 3020
#
# 🔁 Translating batch 3020 to 3029...
# ✅ Saved checkpoint at index 3030
#
# 🔁 Translating batch 3030 to 3039...
# ✅ Saved checkpoint at index 3040
#
# 🔁 Translating batch 3040 to 3049...
# ✅ Saved checkpoint at index 3050
#
# 🔁 Translating batch 3050 to 3059...
# ✅ Saved checkpoint at index 3060
#
# 🔁 Translating batch 3060 to 3069...
# ✅ Saved checkpoint at index 3070
#
# 🔁 Translating batch 3070 to 3079...
# ✅ Saved checkpoint at index 3080
#
# 🔁 Translating batch 3080 to 3089...
# ✅ Saved checkpoint at index 3090
#
# 🔁 Translating batch 3090 to 3099...
# ✅ Saved checkpoint at index 3100
#
# 🔁 Translating batch 3100 to 3109...
# ✅ Saved checkpoint at index 3110
#
# 🔁 Translating batch 3110 to 3119...
# ✅ Saved checkpoint at index 3120
#
# 🔁 Translating batch 3120 to 3129...
# ✅ Saved checkpoint at index 3130
#
# 🔁 Translating batch 3130 to 3139...
# ✅ Saved checkpoint at index 3140
#
# 🔁 Translating batch 3140 to 3149...
# ✅ Saved checkpoint at index 3150
#
# 🔁 Translating batch 3150 to 3159...
# ✅ Saved checkpoint at index 3160
#
# 🔁 Translating batch 3160 to 3169...
# ✅ Saved checkpoint at index 3170
#
# 🔁 Translating batch 3170 to 3179...
# ✅ Saved checkpoint at index 3180
#
# 🔁 Translating batch 3180 to 3189...
# ✅ Saved checkpoint at index 3190
#
# 🔁 Translating batch 3190 to 3199...
# ✅ Saved checkpoint at index 3200
#
# 🔁 Translating batch 3200 to 3209...
# ✅ Saved checkpoint at index 3210
#
# 🔁 Translating batch 3210 to 3219...
# ✅ Saved checkpoint at index 3220
#
# 🔁 Translating batch 3220 to 3229...
# ✅ Saved checkpoint at index 3230
#
# 🔁 Translating batch 3230 to 3239...
# ✅ Saved checkpoint at index 3240
#
# 🔁 Translating batch 3240 to 3249...
# ✅ Saved checkpoint at index 3250
#
# 🔁 Translating batch 3250 to 3259...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       1 processor = OllamaBatchTranslator(
#       2     source_file="paralel_cub_200_2011_captions.json",
#       3     output_file="ollama_translated.json",
#       4     batch_size=10
#       5 )
# ----> 6 processor.run()
#
# Cell In[2], line 73, in OllamaBatchTranslator.run(self)
#      70 batch_texts = [item[2] for item in batch_entries]
#      72 print(f"\n🔁 Translating batch {index} to {index + len(batch_entries) - 1}...")
# ---> 73 translations = self._translate_batch(batch_texts)
#      75 for i, (entry_idx, cap_idx, _) in enumerate(batch_entries):
#      76     self.source_data["dataset"][entry_idx]["captions"][cap_idx]["indo"] = (
#      77         translations[i] if i < len(translations) else "[MISSING TRANSLATION]"
#      78     )
#
# Cell In[2], line 42, in OllamaBatchTranslator._translate_batch(self, batch)
#      36 prompt_lines = "\n".join([f"{i+1}. {text}" for i, text in enumerate(batch)])
#      37 prompt = (
#      38     "Terjemahkan semua kalimat ini ke dalam Bahasa Indonesia secara kontekstual dan ilmiah sesuai bidang ornitologi:\n\n"
#      39     f"{prompt_lines}\n\nJawaban:"
#      40 )
# ---> 42 result = subprocess.run(
#      43     ["ollama", "run", self.model],
#      44     input=prompt.encode(),
#      45     stdout=subprocess.PIPE,
#      46     stderr=subprocess.PIPE
#      47 )
#      48 output = result.stdout.decode("utf-8").strip()
#      50 lines = output.split("\n")
#
# File c:\Users\cacai\anaconda3\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\cacai\anaconda3\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Users\cacai\anaconda3\Lib\subprocess.py:1628, in Popen._communicate(self, input, endtime, orig_timeout)
#    1624 # Wait for the reader threads, or time out.  If we time out, the
#    1625 # threads remain reading and the fds left open in case the user
#    1626 # calls communicate again.
#    1627 if self.stdout is not None:
# -> 1628     self.stdout_thread.join(self._remaining_time(endtime))
#    1629     if self.stdout_thread.is_alive():
#    1630         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\cacai\anaconda3\Lib\threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\cacai\anaconda3\Lib\threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:

# %%
output_file = "ollama_translated.json"


with open("ollama_translated.json", "r", encoding="utf-8") as f:
    translated_data = json.load(f)

# Tampilkan 3 entri awal
from pprint import pprint
pprint(translated_data["dataset"][:3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 output_file = "ollama_translated.json"
# ----> 4 with open("ollama_translated.json", "r", encoding="utf-8") as f:
#       5     translated_data = json.load(f)
#       7 # Tampilkan 3 entri awal
#
# File c:\Users\cacai\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ollama_translated.json'

# %%
from pathlib import Path
import json

source_file = "paralel_cub_200_2011_captions.json"
checkpoint_file = Path("ollama_translated.json").parent / "checkpoint.json"
output_file = "ollama_translated_partial.json"

# Load data sumber asli
with open(source_file, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)

print(f"✅ Output hasil parsial disimpan ke: {output_file}")
# Out:
# ✅ Output hasil parsial disimpan ke: ollama_translated_partial.json

# %%
import json
import subprocess
import time
from pathlib import Path

class OllamaBatchTranslator:
    def __init__(self, source_file: str, output_file: str, batch_size=10, model="qwen2.5:1.5b"):
        self.source_file = Path(source_file)
        self.output_file = Path(output_file)
        self.batch_size = batch_size
        self.model = model
        self.checkpoint_file = self.output_file.parent / "checkpoint1.json"

        self.stats = self._load_checkpoint() or {
            'processed_index': 0,
            'start_time': time.time()
        }

        self._load_source()

    def _load_checkpoint(self):
        if self.checkpoint_file.exists():
            with open(self.checkpoint_file, 'r', encoding='utf-8') as f:
                return json.load(f)
        return None

    def _save_checkpoint(self):
        with open(self.checkpoint_file, 'w', encoding='utf-8') as f:
            json.dump(self.stats, f, indent=2, ensure_ascii=False)

    def _load_source(self):
        with open(self.source_file, 'r', encoding='utf-8') as f:
            self.source_data = json.load(f)

    def _translate_batch(self, batch):
        prompt_lines = "\n".join([f"{i+1}. {text}" for i, text in enumerate(batch)])
        prompt = (
            "You are a professional translator specialized in ornithology."
            "Translate the following English sentences into accurate Indonesian using correct ornithological terminology:\n"
            f"{prompt_lines}\n\n" +
            "Respond with only the translations, numbered accordingly."
        )

        result = subprocess.run(
            ["ollama", "run", self.model],
            input=prompt.encode(),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE
        )
        output = result.stdout.decode("utf-8").strip()

        lines = output.split("\n")
        translations = []
        for line in lines:
            if "." in line:
                text = line.split(".", 1)[1].strip()
                if text:
                    translations.append(text)
        return translations

    def run(self):
        print("\n=== Starting Translation with Checkpoint Support ===")
        index = self.stats['processed_index']

        all_entries = []
        for entry_idx, entry in enumerate(self.source_data["dataset"]):
            for cap_idx, cap in enumerate(entry["captions"]):
                all_entries.append((entry_idx, cap_idx, cap["english"]))

        while index < len(all_entries):
            batch_entries = all_entries[index:index + self.batch_size]
            batch_texts = [item[2] for item in batch_entries]

            print(f"\n🔁 Translating batch {index} to {index + len(batch_entries) - 1}...")
            translations = self._translate_batch(batch_texts)

            for i, (entry_idx, cap_idx, _) in enumerate(batch_entries):
                self.source_data["dataset"][entry_idx]["captions"][cap_idx]["indo"] = (
                    translations[i] if i < len(translations) else "[MISSING TRANSLATION]"
                )

            index += self.batch_size
            self.stats['processed_index'] = index
            self._save_checkpoint()
            print(f"✅ Saved checkpoint at index {index}")
            time.sleep(1)

        print("\n🎉 Translation complete!")
        with open(self.output_file, 'w', encoding='utf-8') as f:
            json.dump(self.source_data, f, indent=2, ensure_ascii=False)
        print(f"📝 Results saved to: {self.output_file}")

# %%
processor = OllamaBatchTranslator(
    source_file="paralel_cub_200_2011_captions.json",
    output_file="ollama_translated1.json",
    batch_size=25
)
processor.run()
# Out:
# === Starting Translation with Checkpoint Support ===
#
# 🔁 Translating batch 0 to 24...
# ✅ Saved checkpoint at index 25
#
# 🔁 Translating batch 25 to 49...
# ✅ Saved checkpoint at index 50
#
# 🔁 Translating batch 50 to 74...
# ✅ Saved checkpoint at index 75
#
# 🔁 Translating batch 75 to 99...
# ✅ Saved checkpoint at index 100
#
# 🔁 Translating batch 100 to 124...
# ✅ Saved checkpoint at index 125
#
# 🔁 Translating batch 125 to 149...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       1 processor = OllamaBatchTranslator(
#       2     source_file="paralel_cub_200_2011_captions.json",
#       3     output_file="ollama_translated1.json",
#       4     batch_size=25
#       5 )
# ----> 6 processor.run()
#
# Cell In[2], line 75, in OllamaBatchTranslator.run(self)
#      72 batch_texts = [item[2] for item in batch_entries]
#      74 print(f"\n🔁 Translating batch {index} to {index + len(batch_entries) - 1}...")
# ---> 75 translations = self._translate_batch(batch_texts)
#      77 for i, (entry_idx, cap_idx, _) in enumerate(batch_entries):
#      78     self.source_data["dataset"][entry_idx]["captions"][cap_idx]["indo"] = (
#      79         translations[i] if i < len(translations) else "[MISSING TRANSLATION]"
#      80     )
#
# Cell In[2], line 44, in OllamaBatchTranslator._translate_batch(self, batch)
#      36 prompt_lines = "\n".join([f"{i+1}. {text}" for i, text in enumerate(batch)])
#      37 prompt = (
#      38     "You are a professional translator specialized in ornithology."
#      39     "Translate the following English sentences into accurate Indonesian using correct ornithological terminology:\n"
#      40     f"{prompt_lines}\n\n" +
#      41     "Respond with only the translations, numbered accordingly."
#      42 )
# ---> 44 result = subprocess.run(
#      45     ["ollama", "run", self.model],
#      46     input=prompt.encode(),
#      47     stdout=subprocess.PIPE,
#      48     stderr=subprocess.PIPE
#      49 )
#      50 output = result.stdout.decode("utf-8").strip()
#      52 lines = output.split("\n")
#
# File c:\Users\cacai\anaconda3\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\cacai\anaconda3\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Users\cacai\anaconda3\Lib\subprocess.py:1628, in Popen._communicate(self, input, endtime, orig_timeout)
#    1624 # Wait for the reader threads, or time out.  If we time out, the
#    1625 # threads remain reading and the fds left open in case the user
#    1626 # calls communicate again.
#    1627 if self.stdout is not None:
# -> 1628     self.stdout_thread.join(self._remaining_time(endtime))
#    1629     if self.stdout_thread.is_alive():
#    1630         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\cacai\anaconda3\Lib\threading.py:1149, in Thread.join(self, timeout)
#    1146     raise RuntimeError("cannot join current thread")
#    1148 if timeout is None:
# -> 1149     self._wait_for_tstate_lock()
#    1150 else:
#    1151     # the behavior of a negative timeout isn't documented, but
#    1152     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1153     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\cacai\anaconda3\Lib\threading.py:1169, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166     return
#    1168 try:
# -> 1169     if lock.acquire(block, timeout):
#    1170         lock.release()
#    1171         self._stop()
#
# KeyboardInterrupt:

# %%
from pathlib import Path
import json

source_file = "paralel_cub_200_2011_captions.json"
checkpoint_file = Path("ollama_translated1.json").parent / "checkpoint1.json"
output_file = "ollama_translated_partial1.json"

# Load data sumber asli
with open(source_file, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)

print(f"✅ Output hasil parsial disimpan ke: {output_file}")
# Out:
# ✅ Output hasil parsial disimpan ke: ollama_translated_partial1.json
